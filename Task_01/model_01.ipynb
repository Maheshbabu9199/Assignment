# %%
# !pip install ultralytics -q
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt") # loading the pre-trained model
model.train(data = "/content/drive/MyDrive/Mahesh_ColabNotebooks/data.yaml", epochs=150)
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train3/weights/best.pt")# Predictions only for person class
infer.predict("//content/drive/MyDrive/Mahesh_ColabNotebooks/pexels-yaroslav-shuraev-9632701 (2160p).mp4",save=True,conf=0.4,classes=[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-898c2bc871f8> in <cell line: 1>()
# ----> 1 infer = YOLO("/content/runs/detect/train3/weights/best.pt")# Predictions only for person class
#       2 infer.predict("//content/drive/MyDrive/Mahesh_ColabNotebooks/pexels-yaroslav-shuraev-9632701 (2160p).mp4",save=True,conf=0.4,classes=[1])
#
# NameError: name 'YOLO' is not defined
